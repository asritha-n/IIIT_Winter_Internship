# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
results = model(source='..\\datasets\\video_1.mp4', show=True, conf=0.4, save=True)  # predict on an image
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/240) C:\Users\user1\Desktop\iiit_hyd_internship\datasets\video_1.mp4: 640x448 6 persons, 1 clock, 152.9ms
# video 1/1 (frame 2/240) C:\Users\user1\Desktop\iiit_hyd_internship\datasets\video_1.mp4: 640x448 6 persons, 74.6ms
# video 1/1 (frame 3/240) C:\Users\user1\Desktop\iiit_hyd_internship\datasets\video_1.mp4: 640x448 6 persons, 1 clock, 75.8ms
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
results = model(source='..\\datasets\\video_2.mp4', show=True, conf=0.4, save=True)  # predict on an image
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/929) c:\Users\user1\Desktop\iiit_hyd_internship\notebooks\..\datasets\video_2.mp4: 384x640 13 persons, 90.6ms
# video 1/1 (frame 2/929) c:\Users\user1\Desktop\iiit_hyd_internship\notebooks\..\datasets\video_2.mp4: 384x640 12 persons, 66.3ms
# video 1/1 (frame 3/929) c:\Users\user1\Desktop\iiit_hyd_internship\notebooks\..\datasets\video_2.mp4: 384x640 12 persons, 64.3ms
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')  # load a pretrained model (recommended for training)
results = model(source='..\\datasets\\video_1.mp4', show=True, conf=0.4, save=True)  # predict on an image
results = model(source='..\\datasets\\video_2.mp4', show=True, conf=0.4, save=True)  # predict on an image
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/240) c:\Users\user1\Desktop\iiit_hyd_internship\notebooks\..\datasets\video_1.mp4: 640x448 7 persons, 1 clock, 128.0ms
# video 1/1 (frame 2/240) c:\Users\user1\Desktop\iiit_hyd_internship\notebooks\..\datasets\video_1.mp4: 640x448 7 persons, 1 clock, 96.1ms
# video 1/1 (frame 3/240) c:\Users\user1\Desktop\iiit_hyd_internship\notebooks\..\datasets\video_1.mp4: 640x448 6 persons, 1 clock, 108.4ms
# ...
