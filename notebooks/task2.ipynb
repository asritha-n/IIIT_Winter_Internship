# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
results = model.train(data="C:\\Users\\user1\\Desktop\\iiit_hyd_internship\\datasets\\coco8\\coco8.yaml", epochs=3)
# Out:
# New https://pypi.org/project/ultralytics/8.3.222 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.218  Python-3.11.3 torch-2.9.0+cu126 CPU (AMD Ryzen 7 PRO 5850U with Radeon Graphics)
# ...

# %%
from ultralytics.utils.downloads import download

download('https://ultralytics.com/assets/coco8-seg.zip')
# Out:
# ...
# Unzipping c:\Users\user1\Desktop\iiit_hyd_internship\notebooks\coco8-seg.zip to C:\Users\user1\Desktop\iiit_hyd_internship\notebooks\coco8-seg...: 100% ━━━━━━━━━━━━ 25/25 562.0files/s 0.0s

# %%
from ultralytics import YOLO
model = YOLO("yolov8n-seg.pt")
results = model.train(data="C:\\Users\\user1\\Desktop\\iiit_hyd_internship\\datasets\\coco8-seg\\coco8-seg.yaml", epochs=3)
# Out:
# New https://pypi.org/project/ultralytics/8.3.222 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.218  Python-3.11.3 torch-2.9.0+cu126 CPU (AMD Ryzen 7 PRO 5850U with Radeon Graphics)
# ...
